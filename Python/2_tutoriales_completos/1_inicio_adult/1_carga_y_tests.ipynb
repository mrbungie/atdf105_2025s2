# %% [markdown]
# # Carga y Tests en Adult
#
# Carga del dataset Adult y pruebas/estadistica descriptiva inicial.

# %%
import pandas as pd
from scipy import stats

df = pd.read_csv("adult.csv")

df.head()
# Out:
#    age         workclass  education_num      marital_status  \
# 0   39         State-gov             13       Never-married
# 1   50  Self-emp-not-inc             13  Married-civ-spouse
# 2   38           Private              9            Divorced
# 3   53           Private              7  Married-civ-spouse
# 4   28           Private             13  Married-civ-spouse
#
#           occupation   relationship   race  gender  hours_per_week  \
# 0       Adm-clerical  Not-in-family  White    Male              40
# 1    Exec-managerial        Husband  White    Male              13
# 2  Handlers-cleaners  Not-in-family  White    Male              40
# 3  Handlers-cleaners        Husband  Other    Male              40
# 4     Prof-specialty           Wife  Other  Female              40
#
#   native_country  capital income_status
# 0  United-States     2174         <=50K
# 1  United-States        0         <=50K
# 2  United-States        0         <=50K
# 3  United-States        0         <=50K
# 4          Other        0         <=50K

# %%
df.describe(include="all").transpose().head(12)
# Out:
#                   count unique                 top   freq         mean  \
# age             45222.0    NaN                 NaN    NaN    38.547941
# workclass         45222      7             Private  33307          NaN
# education_num   45222.0    NaN                 NaN    NaN     10.11846
# marital_status    45222      7  Married-civ-spouse  21055          NaN
# occupation        45222     14        Craft-repair   6020          NaN
# relationship      45222      6             Husband  18666          NaN
# race              45222      2               White  38903          NaN
# gender            45222      2                Male  30527          NaN
# hours_per_week  45222.0    NaN                 NaN    NaN    40.938017
# native_country    45222      2       United-States  41292          NaN
# capital         45222.0    NaN                 NaN    NaN  1012.834925
# income_status     45222      2               <=50K  34014          NaN
#
#                        std     min   25%   50%   75%      max
# age               13.21787    17.0  28.0  37.0  47.0     90.0
# workclass              NaN     NaN   NaN   NaN   NaN      NaN
# education_num     2.552881     1.0   9.0  10.0  13.0     16.0
# marital_status         NaN     NaN   NaN   NaN   NaN      NaN
# occupation             NaN     NaN   NaN   NaN   NaN      NaN
# relationship           NaN     NaN   NaN   NaN   NaN      NaN
# race                   NaN     NaN   NaN   NaN   NaN      NaN
# gender                 NaN     NaN   NaN   NaN   NaN      NaN
# hours_per_week   12.007508     1.0  40.0  40.0  45.0     99.0
# native_country         NaN     NaN   NaN   NaN   NaN      NaN
# capital         7530.31538 -4356.0   0.0   0.0   0.0  99999.0
# income_status          NaN     NaN   NaN   NaN   NaN      NaN

# %%
# Ejemplo de contraste simple: diferencia de horas por nivel de ingreso
x = df.loc[df["income_status"] == "<=50K", "hours_per_week"].dropna()
y = df.loc[df["income_status"] == ">50K", "hours_per_week"].dropna()

# %%
stat, pvalue = stats.ttest_ind(x, y, equal_var=False)
print({"t_stat": stat, "pvalue": pvalue})
# Out:
# {'t_stat': np.float64(-52.26004139110421), 'pvalue': np.float64(0.0)}

# %%
df["income_status"].value_counts(normalize=True)
# Out:
# income_status
# <=50K    0.752156
# >50K     0.247844
# Name: proportion, dtype: float64
