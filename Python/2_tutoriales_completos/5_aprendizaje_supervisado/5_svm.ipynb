# %% [markdown]
# # SVM - Titanic
#
# Objetivo: entrenar el modelo y evaluar con matriz de confusion, accuracy, precision y recall.

# %% [markdown]
# ## 1) Librerias

# %%
# !pip install pandas matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (3.0.1)
# Requirement already satisfied: matplotlib in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (1.8.0)
# Requirement already satisfied: numpy>=2.3.3 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from matplotlib) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/goviedb/Development/UNAB/Teaching/R/my-r-project/Ejemplos/.venv_nb/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Datos
import pandas as pd

# %%
# Calculo numerico
import numpy as np

# %%
# Modelo

# %%
from sklearn.svm import SVC

# %%
# Metricas
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, classification_report

# %% [markdown]
# ## 2) Cargar datos

# %%
# Leer archivo
titanic = pd.read_csv("titanic.csv")

# %%
# Vista rapida
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Tipos de columnas
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# ## 3) Preparar datos

# %%
# Convertir tipos
titanic["Survived"] = titanic["Survived"].astype(int)

# %%
# Convertir tipos
titanic["Sex"] = titanic["Sex"].astype("category")

# %%
# Convertir tipos
titanic["Pclass"] = titanic["Pclass"].astype("category")

# %%
# Eliminar faltantes clave
datos_modelo = titanic.dropna(subset=["Age", "Embarked"])

# %%
# Seleccionar variables
datos_modelo = datos_modelo[["Survived", "Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]]

# %%
# Resumen
datos_modelo.describe(include="all")
# Out:
#           Survived  Pclass   Sex         Age       SibSp       Parch  \
# count   712.000000   712.0   712  712.000000  712.000000  712.000000
# unique         NaN     3.0     2         NaN         NaN         NaN
# top            NaN     3.0  male         NaN         NaN         NaN
# freq           NaN   355.0   453         NaN         NaN         NaN
# mean      0.404494     NaN   NaN   29.642093    0.514045    0.432584
# std       0.491139     NaN   NaN   14.492933    0.930692    0.854181
# min       0.000000     NaN   NaN    0.420000    0.000000    0.000000
# 25%       0.000000     NaN   NaN   20.000000    0.000000    0.000000
# 50%       0.000000     NaN   NaN   28.000000    0.000000    0.000000
# 75%       1.000000     NaN   NaN   38.000000    1.000000    1.000000
# max       1.000000     NaN   NaN   80.000000    5.000000    6.000000
#
#               Fare Embarked
# count   712.000000      712
# unique         NaN        3
# top            NaN        S
# freq           NaN      554
# mean     34.567251      NaN
# std      52.938648      NaN
# min       0.000000      NaN
# 25%       8.050000      NaN
# 50%      15.645850      NaN
# 75%      33.000000      NaN
# max     512.329200      NaN

# %% [markdown]
# ## 4) Separar entrenamiento y prueba (80/20)

# %%
# Muestreo reproducible
np.random.seed(123)

# %%
# Indices de entrenamiento
indices = np.random.choice(datos_modelo.index, size=int(0.8 * len(datos_modelo)), replace=False)

# %%
# Conjuntos
entrenamiento = datos_modelo.loc[indices].copy()
prueba = datos_modelo.drop(indices).copy()

# %% [markdown]
# ## 5) Crear matriz de entrada

# %%
# Variables X entrenamiento
X_train = entrenamiento[["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]].copy()

# %%
# Variable y entrenamiento
y_train = entrenamiento["Survived"].copy()

# %%
# Variables X prueba
X_test = prueba[["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]].copy()

# %%
# Variable y prueba
y_test = prueba["Survived"].copy()

# %%
# Dummies en entrenamiento
X_train = pd.get_dummies(X_train, drop_first=False)

# %%
# Dummies en prueba
X_test = pd.get_dummies(X_test, drop_first=False)

# %%
# Alinear columnas
X_train, X_test = X_train.align(X_test, join="left", axis=1, fill_value=0)

# %% [markdown]
# ## 6) Entrenar modelo

# %%
# Crear modelo

# %%
modelo = SVC(probability=True, random_state=123)

# %%
modelo.fit(X_train, y_train)
# Out:
# SVC(probability=True, random_state=123)

# %% [markdown]
# ## 7) Predecir

# %%
# Probabilidades entrenamiento

# %%
prob_train = modelo.predict_proba(X_train)[:, 1]

# %%
pred_train = (prob_train > 0.5).astype(int)

# %%
# Probabilidades prueba

# %%
prob_test = modelo.predict_proba(X_test)[:, 1]

# %%
pred_test = (prob_test > 0.5).astype(int)

# %% [markdown]
# ## 8) Evaluacion

# %%
# Matriz de confusion entrenamiento
cm = confusion_matrix(y_train, pred_train)
pd.DataFrame(cm, index=['Real_0', 'Real_1'], columns=['Pred_0', 'Pred_1'])
# Out:
#         Pred_0  Pred_1
# Real_0     304      37
# Real_1     147      81

# %%
# Reporte de clasificacion
print(classification_report(y_train, pred_train, digits=4, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6741    0.8915    0.7677       341
#            1     0.6864    0.3553    0.4682       228
#
#     accuracy                         0.6766       569
#    macro avg     0.6802    0.6234    0.6179       569
# weighted avg     0.6790    0.6766    0.6477       569

# %%
# Matriz de confusion prueba
cm = confusion_matrix(y_test, pred_test)
pd.DataFrame(cm, index=['Real_0', 'Real_1'], columns=['Pred_0', 'Pred_1'])
# Out:
#         Pred_0  Pred_1
# Real_0      80       3
# Real_1      45      15

# %%
# Reporte de clasificacion
print(classification_report(y_test, pred_test, digits=4, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6400    0.9639    0.7692        83
#            1     0.8333    0.2500    0.3846        60
#
#     accuracy                         0.6643       143
#    macro avg     0.7367    0.6069    0.5769       143
# weighted avg     0.7211    0.6643    0.6079       143

# %%
# Accuracy entrenamiento
accuracy_score(y_train, pred_train)
# Out:
# 0.6766256590509666

# %%
# Precision entrenamiento
precision_score(y_train, pred_train, zero_division=0)
# Out:
# 0.6864406779661016

# %%
# Recall entrenamiento
recall_score(y_train, pred_train, zero_division=0)
# Out:
# 0.35526315789473684

# %%
# Accuracy prueba
accuracy_score(y_test, pred_test)
# Out:
# 0.6643356643356644

# %%
# Precision prueba
precision_score(y_test, pred_test, zero_division=0)
# Out:
# 0.8333333333333334

# %%
# Recall prueba
recall_score(y_test, pred_test, zero_division=0)
# Out:
# 0.25

# %%
# Tabla resumen
resumen_metricas = pd.DataFrame({
    "Metrica": ["Accuracy", "Precision", "Recall"],
    "Entrenamiento": [
        accuracy_score(y_train, pred_train),
        precision_score(y_train, pred_train, zero_division=0),
        recall_score(y_train, pred_train, zero_division=0),
    ],
    "Prueba": [
        accuracy_score(y_test, pred_test),
        precision_score(y_test, pred_test, zero_division=0),
        recall_score(y_test, pred_test, zero_division=0),
    ]
})
resumen_metricas
# Out:
#      Metrica  Entrenamiento    Prueba
# 0   Accuracy       0.676626  0.664336
# 1  Precision       0.686441  0.833333
# 2     Recall       0.355263  0.250000
