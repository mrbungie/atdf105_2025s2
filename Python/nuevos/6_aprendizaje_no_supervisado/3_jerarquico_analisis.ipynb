# %% [markdown]
# # Analisis Jerarquico Comparativo
#
# Comparacion de metodos de linkage y evaluacion de clusters jerarquicos.
#
# Conversion conceptual 1:1 desde el ejemplo R homologo.

# %%
from pathlib import Path


def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "R").exists():
            return candidate
    raise FileNotFoundError("No se encontro la carpeta R del repositorio")

REPO_ROOT = find_repo_root(Path.cwd())
print("Repo root:", REPO_ROOT)

# %%
import pandas as pd
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

iris_path = REPO_ROOT / "R" / "nuevos" / "6_aprendizaje_no_supervisado" / "data" / "iris.csv"
df = pd.read_csv(iris_path)
X = df.drop(columns=["variety"])
X_scaled = StandardScaler().fit_transform(X)

methods = ["ward", "complete", "average", "single"]
results = []
for m in methods:
    Z = linkage(X_scaled, method=m)
    labels = fcluster(Z, t=3, criterion="maxclust")
    sil = silhouette_score(X_scaled, labels)
    results.append((m, sil))

print(pd.DataFrame(results, columns=["method", "silhouette"]).sort_values("silhouette", ascending=False))
